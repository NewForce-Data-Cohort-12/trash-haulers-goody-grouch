# %%
import pandas as pd
import geopandas as gpd

# %%
trash_data = gpd.read_file('./trash_hauler_report.csv')
trash_data
# Out:
#       Request Number Date Opened                               Request  \
# 0              25270    11/01/17                      Trash - Backdoor
# 1              25274    11/01/17  Trash - Curbside/Alley Missed Pickup
# 2              25276    11/01/17  Trash - Curbside/Alley Missed Pickup
# 3              25307    11/01/17  Trash - Curbside/Alley Missed Pickup
# 4              25312    11/01/17  Trash - Curbside/Alley Missed Pickup
# ...              ...         ...                                   ...
# 20221         267125    11/01/19  Trash - Curbside/Alley Missed Pickup
# 20222         267126    11/01/19  Trash - Curbside/Alley Missed Pickup
# 20223         267130    11/01/19  Trash - Curbside/Alley Missed Pickup
# 20224         267134    11/01/19  Trash - Curbside/Alley Missed Pickup
# 20225         267137    11/01/19  Trash - Curbside/Alley Missed Pickup
#
#                                              Description  \
# 0      house with the wheel chair ramp, they share dr...
# 1                               Curb/Trash miss Tuesday.
# 2                               Curb/trash miss Tuesday.
# 3                                                 missed
# 4                      Missed the even side of the road.
# ...                                                  ...
# 20221                          MISSED...NEIGHBORS MISSED
# 20222                                       entire alley
# 20223                                     missed several
# 20224  Caller stated trash was missed & were only pic...
# 20225                     possibly others missed as well
#
#                                         Incident Address Zip Code  \
# 0                                         3817 Crouch Dr    37207
# 1                                  4028 Clarksville Pike    37218
# 2                                    6528 Thunderbird Dr    37209
# 3                                   2603 old matthews rd    37207
# 4                                          604 croley dr    37209
# ...                                                  ...      ...
# 20221                             2731 Murfreesboro Pike    37013
# 20222  1621 Long Ave, Nashville, TN 37206, United States    37206
# 20223  2943 Windemere Cir, Nashville, TN 37214, Unite...    37214
# 20224  3325 Murfreesboro Pike, Nashville, TN 37013, U...    37013
# 20225  604 Somerset Ct, Nashville, TN 37217, United S...    37217
#
#       Trash Hauler Trash Route Council District      State Plan X  \
# 0        RED RIVER        3205                2  1727970.41206786
# 1        RED RIVER        4202                1  1721259.36568104
# 2        RED RIVER        4205               20  1707026.75348931
# 3        WASTE IND        2206                2  1735691.77097349
# 4        RED RIVER        4203               20  1710185.77229504
# ...            ...         ...              ...               ...
# 20221    RED RIVER        4502               32  1781137.26293528
# 20222        METRO        9508                6  1749711.39882271
# 20223    RED RIVER        1502               15  1770293.38813099
# 20224    RED RIVER        4502               32  1785224.99799806
# 20225    RED RIVER        2505               29  1781360.32310215
#
#            State Plan Y
# 0      686779.478088711
# 1      685444.799565154
# 2      659887.471571312
# 3      685027.245922773
# 4      664205.101065545
# ...                 ...
# 20221  632448.551143857
# 20222  669201.601569129
# 20223  674936.303809043
# 20224  627146.400187231
# 20225  637742.006845765
#
# [20226 rows x 11 columns]

# %%
# Finding unique values for the Request column 
pd.unique(trash_data['Request'])
# Out:
# array(['Trash - Backdoor', 'Trash - Curbside/Alley Missed Pickup',
#        'Trash Collection Complaint', 'Damage to Property'], dtype=object)

# %%
backdoor = trash_data.loc[trash_data['Request'] == 'Trash - Backdoor']
backdoor.shape
# Out:
# (2629, 11)

# %%
cs_alley = trash_data.loc[trash_data['Request'] == 'Trash - Curbside/Alley Missed Pickup']
cs_alley.shape
# Out:
# (15028, 11)

# %%
complaint = trash_data.loc[trash_data['Request'] == 'Trash Collection Complaint']
#complaint

# %%
contains_miss = complaint['Description'].str.contains('miss', case = 'False', na ='False')
#contains_miss
# Out:
# C:\Users\EpicWork\AppData\Local\Temp\ipykernel_37736\3712832755.py:1: FutureWarning: Allowing a non-bool 'na' in obj.str.contains is deprecated and will raise in a future version.
#   contains_miss = complaint['Description'].str.contains('miss', case = 'False', na ='False')

# %%
miss_complaint = complaint[contains_miss]
miss_complaint.shape
# Out:
# (453, 11)

# %%
miss_all = pd.concat([backdoor, cs_alley, miss_complaint], ignore_index = 'True')

# %%
miss_all['Short Address'] = miss_all['Incident Address'].str.split(',', n=1).str[0]
miss_all['Short Address'] = miss_all['Short Address'].str.lower()
miss_all
# Out:
#       Request Number Date Opened                     Request  \
# 0              25270    11/01/17            Trash - Backdoor
# 1              25692    11/02/17            Trash - Backdoor
# 2              25775    11/02/17            Trash - Backdoor
# 3              25802    11/02/17            Trash - Backdoor
# 4              25858    11/03/17            Trash - Backdoor
# ...              ...         ...                         ...
# 18105         266466    10/31/19  Trash Collection Complaint
# 18106         266628    10/31/19  Trash Collection Complaint
# 18107         266708    11/01/19  Trash Collection Complaint
# 18108         266710    11/01/19  Trash Collection Complaint
# 18109         266732    11/01/19  Trash Collection Complaint
#
#                                              Description  \
# 0      house with the wheel chair ramp, they share dr...
# 1      Backdoor/miss for last Friday. Does not unders...
# 2      Missed trash pickup said has been picking up b...
# 3                                                Missed.
# 4      Missed- she said her grandson was over yesterd...
# ...                                                  ...
# 18105  Paid/Backdoor-Trash missed last Thursday, does...
# 18106  Disabled caller stated she is keep getting mis...
# 18107  Caller stated her trash has been missed for 2 ...
# 18108  Trash/has been missed for weeks in a row, curb...
# 18109  Caller stated her trash misses her trash all t...
#
#                                         Incident Address Zip Code  \
# 0                                         3817 Crouch Dr    37207
# 1                                     3041 Fieldstone Dr    37013
# 2                                           4625 long br    37013
# 3                                      4828 Cimarron Way    37013
# 4                                      2005 Lebanon Pike    37210
# ...                                                  ...      ...
# 18105  809 Winthorne Ct, Nashville, TN 37217, United ...    37217
# 18106  1719 Windover Dr, Nashville, TN 37218, United ...    37218
# 18107  4305 Granny White Pike, Nashville, TN 37204, U...    37204
# 18108  3325 Murfreesboro Pike, Nashville, TN 37013, U...    37013
# 18109  2114 Vine Hill Rd, Nashville, TN 37204, United...    37204
#
#       Trash Hauler Trash Route Council District      State Plan X  \
# 0        RED RIVER        3205                2  1727970.41206786
# 1        RED RIVER        3504               29  1785677.15882833
# 2        RED RIVER        4505               28  1770350.41605229
# 3        RED RIVER        3404               30  1766186.56409375
# 4        RED RIVER        1504               15   1760561.7630735
# ...            ...         ...              ...               ...
# 18105    RED RIVER        1402               16  1759043.58424902
# 18106    RED RIVER        4202                2  1718308.69339541
# 18107    RED RIVER        3302               25  1731857.80036635
# 18108    RED RIVER        4502               32  1785224.99799806
# 18109        METRO        9406               17  1741197.38231891
#
#            State Plan Y           Short Address
# 0      686779.478088711          3817 crouch dr
# 1      633139.246264943      3041 fieldstone dr
# 2      634143.871818357            4625 long br
# 3      629785.602877192       4828 cimarron way
# 4      665276.001224629       2005 lebanon pike
# ...                 ...                     ...
# 18105  651549.019214337        809 winthorne ct
# 18106  680762.907491275        1719 windover dr
# 18107  644223.201524295  4305 granny white pike
# 18108  627146.400187231  3325 murfreesboro pike
# 18109   655129.23648106       2114 vine hill rd
#
# [18110 rows x 12 columns]

# %%
miss_count_by_address = miss_all['Short Address'].value_counts().reset_index(name='Missed Pickups')
#miss_count_by_address = miss_count_by_address.to_frame()
miss_count_by_address
# Out:
#                   Short Address  Missed Pickups
# 0       110 george l davis blvd              27
# 1        12546 old hickory blvd              21
# 2      5135 hickory hollow pkwy              20
# 3               802 crescent rd              19
# 4                  1584 bell rd              19
# ...                         ...             ...
# 11305             739 rodney dr               1
# 11306           3805 elkins ave               1
# 11307      800 old hickory blvd               1
# 11308        631 blackstone ave               1
# 11309         2114 vine hill rd               1
#
# [11310 rows x 2 columns]

# %%
frequently_missed = miss_count_by_address.loc[miss_count_by_address['Missed Pickups'] > 1]
frequently_missed
# Out:
#                  Short Address  Missed Pickups
# 0      110 george l davis blvd              27
# 1       12546 old hickory blvd              21
# 2     5135 hickory hollow pkwy              20
# 3              802 crescent rd              19
# 4                 1584 bell rd              19
# ...                        ...             ...
# 3362          321 charmaine ct               2
# 3363           2243 foster ave               2
# 3364           120 islandia dr               2
# 3365        89 riverpoint pass               2
# 3366     115 rosa l parks blvd               2
#
# [3367 rows x 2 columns]

# %%
frequently_missed['Fine Amount'] = (frequently_missed['Missed Pickups'] - 1) * 200
frequently_missed
# Out:
# C:\Users\EpicWork\AppData\Local\Temp\ipykernel_37736\825867008.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   frequently_missed['Fine Amount'] = (frequently_missed['Missed Pickups'] - 1) * 200
#                  Short Address  Missed Pickups  Fine Amount
# 0      110 george l davis blvd              27         5200
# 1       12546 old hickory blvd              21         4000
# 2     5135 hickory hollow pkwy              20         3800
# 3              802 crescent rd              19         3600
# 4                 1584 bell rd              19         3600
# ...                        ...             ...          ...
# 3362          321 charmaine ct               2          200
# 3363           2243 foster ave               2          200
# 3364           120 islandia dr               2          200
# 3365        89 riverpoint pass               2          200
# 3366     115 rosa l parks blvd               2          200
#
# [3367 rows x 3 columns]

# %%
total_damages = frequently_missed['Fine Amount'].sum()
def currency_format(amount):
    return "${:,}".format(amount)
formatted_cost = currency_format(total_damages)
print(f"The total amount in damages is {formatted_cost}")
# Out:
# The total amount in damages is $1,360,000

# %% [markdown]
# <h1>Other types of complaints</h1>

# %%
other_complaints = trash_data[~trash_data['Request Number'].isin(miss_all['Request Number'])].reset_index()
other_complaints
# Out:
#       index Request Number Date Opened                     Request  \
# 0         5          25317    11/01/17  Trash Collection Complaint
# 1         6          25325    11/01/17          Damage to Property
# 2        11          25350    11/01/17  Trash Collection Complaint
# 3        13          25366    11/01/17  Trash Collection Complaint
# 4        16          25393    11/01/17  Trash Collection Complaint
# ...     ...            ...         ...                         ...
# 2111  20172         266637    10/31/19          Damage to Property
# 2112  20197         266844    11/01/19  Trash Collection Complaint
# 2113  20200         266891    11/01/19  Trash Collection Complaint
# 2114  20211         267014    11/01/19  Trash Collection Complaint
# 2115  20215         267069    11/01/19  Trash Collection Complaint
#
#                                             Description  \
# 0     left trash cart in middle of driveway instead ...
# 1     Trash/emptied Wednesday & now metal black-mail...
# 2                            Missed- 4th week in a row.
# 3     trash truck took cart \n3 guys on truck did no...
# 4          trash carts all tossed in road after pick up
# ...                                                 ...
# 2111  truck was turning around in dead end and ran i...
# 2112  RESIDENT CAME HOME YESTERDAY TO FIND THAT THE ...
# 2113  garbage truck is cutting the corner too close,...
# 2114  MANAGER SAYS HE WITNESSED THE TRASH TRUCK COME...
# 2115  trash truck broke a limb out of her tree and l...
#
#                                        Incident Address Zip Code Trash Hauler  \
# 0                                        3602 floral dr    37211    RED RIVER
# 1                                      4721 Chalmers Dr    37215    RED RIVER
# 2                                3210 Whites Creek Pike    37207    RED RIVER
# 3                                         2200 osage st    37208        METRO
# 4                                     2720 riverbend dr    37214    RED RIVER
# ...                                                 ...      ...          ...
# 2111   275 April Ln, Nashville, TN 37211, United States    37211    RED RIVER
# 2112         2812 Vaulx Ln, Nashville, Tennessee, 37204    37204        METRO
# 2113    1997 Nashboro Blvd, Nashville, Tennessee, 37217    37217    RED RIVER
# 2114  109 2nd Ave N, Nashville, TN 37201, United States    37201
# 2115      105 Lake Side Ct, Nashville, Tennessee, 37217    37217    RED RIVER
#
#      Trash Route Council District      State Plan X      State Plan Y
# 0           4304               16  1751660.16380723  643215.201072899
# 1           3303               34  1726300.96525064  637078.402244506
# 2           3201                3  1726432.96620837  691919.200296047
# 3           9201               21  1728644.75713234  672074.099109828
# 4           1501               15   1762455.9236539  693225.665703145
# ...          ...              ...               ...               ...
# 2111        3403               27  1759008.19811749  627977.601282386
# 2112        9404               17  1738157.85471319   652143.57915892
# 2113        2505               29  1781292.39629326  639805.438008825
# 2114                           19  1739543.39981605  666600.801041047
# 2115        3501               29   1789264.9987788  640868.001440132
#
# [2116 rows x 12 columns]

# %% [markdown]
# <h1>Investigating metro crews vs contractor performance</h1>

# %% [markdown]
# <h2>Metro Performance</h2>

# %%
metro = miss_all.loc[miss_all['Trash Hauler'].str.lower() == 'metro'].reset_index()
#metro

# %%
metro_miss_count = metro['Short Address'].value_counts().reset_index(name='Missed Pickups')

# %%
metro_freq_miss = metro_miss_count.loc[metro_miss_count['Missed Pickups'] > 1]
metro_freq_miss['Fine Amount'] = (metro_freq_miss['Missed Pickups'] - 1) * 200
metro_freq_miss
# Out:
# C:\Users\EpicWork\AppData\Local\Temp\ipykernel_37736\196924443.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   metro_freq_miss['Fine Amount'] = (metro_freq_miss['Missed Pickups'] - 1) * 200
#                Short Address  Missed Pickups  Fine Amount
# 0       1816 jo johnston ave              18         3400
# 1    110 george l davis blvd              17         3200
# 2          2813 delaware ave              12         2200
# 3          2801 delaware ave              11         2000
# 4           2415 brasher ave              10         1800
# ..                       ...             ...          ...
# 551         836 cherokee ave               2          200
# 552             913 west ave               2          200
# 553          1609 lillian st               2          200
# 554      1922 ed temple blvd               2          200
# 555             823 knox ave               2          200
#
# [556 rows x 3 columns]

# %%
metro_damages = metro_freq_miss['Fine Amount'].sum()
metro_format = currency_format(metro_damages)
metro_format
# Out:
# '$215,800'

# %% [markdown]
# <h2>Red River Performance</h2>

# %%
trash_data['Trash Hauler'].unique()
# Out:
# array(['RED RIVER', 'WASTE IND', 'METRO', '', 'Metro'], dtype=object)

# %%
red_river = miss_all.loc[miss_all['Trash Hauler'] == 'RED RIVER'].reset_index()
#red_river

# %%
red_river_miss_count = red_river['Short Address'].value_counts().reset_index(name='Missed Pickups')

# %%
red_river_freq_miss = red_river_miss_count.loc[red_river_miss_count['Missed Pickups'] > 1]
red_river_freq_miss['Fine Amount'] = (red_river_freq_miss['Missed Pickups'] - 1) * 200
red_river_freq_miss
# Out:
# C:\Users\EpicWork\AppData\Local\Temp\ipykernel_37736\2638443975.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   red_river_freq_miss['Fine Amount'] = (red_river_freq_miss['Missed Pickups'] - 1) * 200
#                  Short Address  Missed Pickups  Fine Amount
# 0       12546 old hickory blvd              21         4000
# 1     5135 hickory hollow pkwy              19         3600
# 2                 1584 bell rd              18         3400
# 3              6007 obrien ave              17         3200
# 4              802 crescent rd              17         3200
# ...                        ...             ...          ...
# 2412           468 sunliner dr               2          200
# 2413            1707 porter rd               2          200
# 2414                613 may dr               2          200
# 2415              722 dover rd               2          200
# 2416   2645 old buena vista rd               2          200
#
# [2417 rows x 3 columns]

# %%
red_river_damages = red_river_freq_miss['Fine Amount'].sum()
red_river_format = currency_format(red_river_damages)
red_river_format
# Out:
# '$970,000'

# %% [markdown]
# <h2>Waste Ind Performance</h2>

# %%
waste_ind = miss_all.loc[miss_all['Trash Hauler'] == 'WASTE IND'].reset_index()
#waste_ind

# %%
waste_ind_miss_count = waste_ind['Short Address'].value_counts().reset_index(name='Missed Pickups')

# %%
waste_ind_freq_miss = waste_ind_miss_count.loc[waste_ind_miss_count['Missed Pickups'] > 1]
waste_ind_freq_miss['Fine Amount'] = (waste_ind_freq_miss['Missed Pickups'] - 1) * 200
waste_ind_freq_miss
# Out:
# C:\Users\EpicWork\AppData\Local\Temp\ipykernel_37736\2429048491.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   waste_ind_freq_miss['Fine Amount'] = (waste_ind_freq_miss['Missed Pickups'] - 1) * 200
#           Short Address  Missed Pickups  Fine Amount
# 0      15 hermitage ave              16         3000
# 1        123 37th ave n              10         1800
# 2    1011 elm hill pike              10         1800
# 3       3406 batavia st              10         1800
# 4       1517 12th ave n               7         1200
# ..                  ...             ...          ...
# 223       105 evelyn dr               2          200
# 224          72 lyle ln               2          200
# 225        34 n hill st               2          200
# 226      916 32nd ave n               2          200
# 227      926 32nd ave n               2          200
#
# [228 rows x 3 columns]

# %%
waste_ind_damages = waste_ind_freq_miss['Fine Amount'].sum()
waste_ind_format = currency_format(waste_ind_damages)
waste_ind_format
# Out:
# '$78,200'

# %% [markdown]
# <h1>Finding total missed pickups by route</h1>

# %%
miss_by_route = miss_all['Request Number'].groupby(miss_all['Trash Route']).count().reset_index()
miss_by_route
# Out:
#     Trash Route  Request Number
# 0                           767
# 1          1201             175
# 2          1202              93
# 3         1202S               4
# 4          1203              74
# ..          ...             ...
# 168        9504              44
# 169        9505              58
# 170        9506              67
# 171        9507              76
# 172        9508             120
#
# [173 rows x 2 columns]
